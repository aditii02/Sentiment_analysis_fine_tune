# %%
pip install transformers

# %%
pip install datasets

# %%
pip install evaluate

# %%
pip install transformers[torch]

# %%
from datasets import load_dataset
data = load_dataset("FinGPT/fingpt-sentiment-train")
dataset = data["train"]
X_train =[]
for row in dataset:
  X_train.append(row['input'])
# Out:
# Downloading readme:   0%|          | 0.00/529 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/6.42M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/76772 [00:00<?, ? examples/s]

# %%
X_train1 = X_train[:100]
print(len(X_train1))
print(X_train[9]) # dataset ready
# Out:
# 100
# Financial terms were not disclosed .

# %%
from transformers import pipeline
import torch
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoModelForSequenceClassification

#create a sentence classification pipeline
model = "distilbert-base-uncased-finetuned-sst-2-english"
sentimentanalysis_model = AutoModelForSequenceClassification.from_pretrained(model) # this will create a copy of the BERT model
sentimentanalysis_tokenizer = AutoTokenizer.from_pretrained(model) #this will take up the predefined tokenizer that resides in the model repo
classify = pipeline("sentiment-analysis", model= sentimentanalysis_model,tokenizer = sentimentanalysis_tokenizer)
sentiment_gen = classify(X_train1) # classifying the sentences
print(sentiment_gen)
for r in sentiment_gen:
  print(r)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'NEGATIVE', 'score': 0.9480839371681213}, {'label': 'NEGATIVE', 'score': 0.9632577300071716}, {'label': 'NEGATIVE', 'score': 0.9928142428398132}, {'label': 'POSITIVE', 'score': 0.8527814149856567}, {'label': 'NEGATIVE', 'score': 0.9992583394050598}, {'label': 'POSITIVE', 'score': 0.9638770222663879}, {'label': 'NEGATIVE', 'score': 0.8742483854293823}, {'label': 'POSITIVE', 'score': 0.9984328150749207}, {'label': 'POSITIVE', 'score': 0.9949171543121338}, {'label': 'NEGATIVE', 'score': 0.9989768266677856}, {'label': 'NEGATIVE', 'score': 0.9983569979667664}, {'label': 'NEGATIVE', 'score': 0.9995392560958862}, {'label': 'NEGATIVE', 'score': 0.9950854182243347}, {'label': 'POSITIVE', 'score': 0.9902442097663879}, {'label': 'POSITIVE', 'score': 0.9084116220474243}, {'label': 'NEGATIVE', 'score': 0.9906347393989563}, {'label': 'NEGATIVE', 'score': 0.9988527297973633}, {'label': 'NEGATIVE', 'score': 0.9995718598365784}, {'label': 'POSITIVE', 'score': 0.9995423555374146}, {'label': 'NEGATIVE', 'score': 0.9918495416641235}, {'label': 'NEGATIVE', 'score': 0.8998686671257019}, {'label': 'NEGATIVE', 'score': 0.9734795093536377}, {'label': 'POSITIVE', 'score': 0.9948951601982117}, {'label': 'NEGATIVE', 'score': 0.990011990070343}, {'label': 'NEGATIVE', 'score': 0.9739786982536316}, {'label': 'NEGATIVE', 'score': 0.9977002739906311}, {'label': 'POSITIVE', 'score': 0.9975357055664062}, {'label': 'NEGATIVE', 'score': 0.9989493489265442}, {'label': 'NEGATIVE', 'score': 0.9991675615310669}, {'label': 'NEGATIVE', 'score': 0.9900996088981628}, {'label': 'NEGATIVE', 'score': 0.9984070658683777}, {'label': 'NEGATIVE', 'score': 0.9970765113830566}, {'label': 'POSITIVE', 'score': 0.9989370703697205}, {'label': 'NEGATIVE', 'score': 0.9995086193084717}, {'label': 'NEGATIVE', 'score': 0.9995183944702148}, {'label': 'NEGATIVE', 'score': 0.9833351373672485}, {'label': 'NEGATIVE', 'score': 0.993388295173645}, {'label': 'POSITIVE', 'score': 0.9985187649726868}, {'label': 'POSITIVE', 'score': 0.8480878472328186}, {'label': 'NEGATIVE', 'score': 0.5769117474555969}, {'label': 'POSITIVE', 'score': 0.9963177442550659}, {'label': 'NEGATIVE', 'score': 0.987578809261322}, {'label': 'NEGATIVE', 'score': 0.8080611228942871}, {'label': 'NEGATIVE', 'score': 0.9976599216461182}, {'label': 'NEGATIVE', 'score': 0.9793658256530762}, {'label': 'NEGATIVE', 'score': 0.9317958950996399}, {'label': 'NEGATIVE', 'score': 0.9859726428985596}, {'label': 'NEGATIVE', 'score': 0.9973422884941101}, {'label': 'POSITIVE', 'score': 0.9989578723907471}, {'label': 'NEGATIVE', 'score': 0.9475893974304199}, {'label': 'NEGATIVE', 'score': 0.9977207779884338}, {'label': 'NEGATIVE', 'score': 0.9983214735984802}, {'label': 'NEGATIVE', 'score': 0.9973848462104797}, {'label': 'NEGATIVE', 'score': 0.9997877478599548}, {'label': 'NEGATIVE', 'score': 0.8952195048332214}, {'label': 'NEGATIVE', 'score': 0.9501034617424011}, {'label': 'NEGATIVE', 'score': 0.9996765851974487}, {'label': 'POSITIVE', 'score': 0.7618535757064819}, {'label': 'NEGATIVE', 'score': 0.7166484594345093}, {'label': 'NEGATIVE', 'score': 0.9958139061927795}, {'label': 'NEGATIVE', 'score': 0.9965470433235168}, {'label': 'POSITIVE', 'score': 0.9978285431861877}, {'label': 'POSITIVE', 'score': 0.9923918843269348}, {'label': 'POSITIVE', 'score': 0.9163399934768677}, {'label': 'POSITIVE', 'score': 0.9547298550605774}, {'label': 'NEGATIVE', 'score': 0.9994194507598877}, {'label': 'NEGATIVE', 'score': 0.9807589650154114}, {'label': 'POSITIVE', 'score': 0.9956432580947876}, {'label': 'NEGATIVE', 'score': 0.9986863732337952}, {'label': 'NEGATIVE', 'score': 0.9978311657905579}, {'label': 'NEGATIVE', 'score': 0.9970222115516663}, {'label': 'NEGATIVE', 'score': 0.9963288903236389}, {'label': 'NEGATIVE', 'score': 0.9989801049232483}, {'label': 'NEGATIVE', 'score': 0.7296543717384338}, {'label': 'NEGATIVE', 'score': 0.9996329545974731}, {'label': 'NEGATIVE', 'score': 0.9897058010101318}, {'label': 'NEGATIVE', 'score': 0.9957576394081116} ...
# {'label': 'NEGATIVE', 'score': 0.9480839371681213}
# {'label': 'NEGATIVE', 'score': 0.9632577300071716}
# {'label': 'NEGATIVE', 'score': 0.9928142428398132}
# {'label': 'POSITIVE', 'score': 0.8527814149856567}
# {'label': 'NEGATIVE', 'score': 0.9992583394050598}
# {'label': 'POSITIVE', 'score': 0.9638770222663879}
# {'label': 'NEGATIVE', 'score': 0.8742483854293823}
# {'label': 'POSITIVE', 'score': 0.9984328150749207}
# {'label': 'POSITIVE', 'score': 0.9949171543121338}
# {'label': 'NEGATIVE', 'score': 0.9989768266677856}
# {'label': 'NEGATIVE', 'score': 0.9983569979667664}
# {'label': 'NEGATIVE', 'score': 0.9995392560958862}
# {'label': 'NEGATIVE', 'score': 0.9950854182243347}
# {'label': 'POSITIVE', 'score': 0.9902442097663879}
# {'label': 'POSITIVE', 'score': 0.9084116220474243}
# {'label': 'NEGATIVE', 'score': 0.9906347393989563}
# {'label': 'NEGATIVE', 'score': 0.9988527297973633}
# {'label': 'NEGATIVE', 'score': 0.9995718598365784}
# {'label': 'POSITIVE', 'score': 0.9995423555374146}
# {'label': 'NEGATIVE', 'score': 0.9918495416641235}
# {'label': 'NEGATIVE', 'score': 0.8998686671257019}
# {'label': 'NEGATIVE', 'score': 0.9734795093536377}
# {'label': 'POSITIVE', 'score': 0.9948951601982117}
# {'label': 'NEGATIVE', 'score': 0.990011990070343}
# {'label': 'NEGATIVE', 'score': 0.9739786982536316}
# {'label': 'NEGATIVE', 'score': 0.9977002739906311}
# {'label': 'POSITIVE', 'score': 0.9975357055664062}
# {'label': 'NEGATIVE', 'score': 0.9989493489265442}
# {'label': 'NEGATIVE', 'score': 0.9991675615310669}
# {'label': 'NEGATIVE', 'score': 0.9900996088981628}
# {'label': 'NEGATIVE', 'score': 0.9984070658683777}
# {'label': 'NEGATIVE', 'score': 0.9970765113830566}
# {'label': 'POSITIVE', 'score': 0.9989370703697205}
# {'label': 'NEGATIVE', 'score': 0.9995086193084717}
# {'label': 'NEGATIVE', 'score': 0.9995183944702148}
# {'label': 'NEGATIVE', 'score': 0.9833351373672485}
# {'label': 'NEGATIVE', 'score': 0.993388295173645}
# {'label': 'POSITIVE', 'score': 0.9985187649726868}
# {'label': 'POSITIVE', 'score': 0.8480878472328186}
# {'label': 'NEGATIVE', 'score': 0.5769117474555969}
# {'label': 'POSITIVE', 'score': 0.9963177442550659}
# {'label': 'NEGATIVE', 'score': 0.987578809261322}
# {'label': 'NEGATIVE', 'score': 0.8080611228942871}
# {'label': 'NEGATIVE', 'score': 0.9976599216461182}
# {'label': 'NEGATIVE', 'score': 0.9793658256530762}
# {'label': 'NEGATIVE', 'score': 0.9317958950996399}
# {'label': 'NEGATIVE', 'score': 0.9859726428985596}
# {'label': 'NEGATIVE', 'score': 0.9973422884941101}
# {'label': 'POSITIVE', 'score': 0.9989578723907471}
# {'label': 'NEGATIVE', 'score': 0.9475893974304199}
# {'label': 'NEGATIVE', 'score': 0.9977207779884338}
# {'label': 'NEGATIVE', 'score': 0.9983214735984802}
# {'label': 'NEGATIVE', 'score': 0.9973848462104797}
# {'label': 'NEGATIVE', 'score': 0.9997877478599548}
# {'label': 'NEGATIVE', 'score': 0.8952195048332214}
# {'label': 'NEGATIVE', 'score': 0.9501034617424011}
# {'label': 'NEGATIVE', 'score': 0.9996765851974487}
# {'label': 'POSITIVE', 'score': 0.7618535757064819}
# {'label': 'NEGATIVE', 'score': 0.7166484594345093}
# {'label': 'NEGATIVE', 'score': 0.9958139061927795}
# {'label': 'NEGATIVE', 'score': 0.9965470433235168}
# {'label': 'POSITIVE', 'score': 0.9978285431861877}
# {'label': 'POSITIVE', 'score': 0.9923918843269348}
# {'label': 'POSITIVE', 'score': 0.9163399934768677}
# {'label': 'POSITIVE', 'score': 0.9547298550605774}
# {'label': 'NEGATIVE', 'score': 0.9994194507598877}
# {'label': 'NEGATIVE', 'score': 0.9807589650154114}
# {'label': 'POSITIVE', 'score': 0.9956432580947876}
# {'label': 'NEGATIVE', 'score': 0.9986863732337952}
# {'label': 'NEGATIVE', 'score': 0.9978311657905579}
# {'label': 'NEGATIVE', 'score': 0.9970222115516663}
# {'label': 'NEGATIVE', 'score': 0.9963288903236389}
# {'label': 'NEGATIVE', 'score': 0.9989801049232483}
# {'label': 'NEGATIVE', 'score': 0.7296543717384338}
# {'label': 'NEGATIVE', 'score': 0.9996329545974731}
# {'label': 'NEGATIVE', 'score': 0.9897058010101318}
# {'label': 'NEGATIVE', 'score': 0.9957576394081116}
# {'label': 'NEGATIVE', 'score': 0.9997318387031555}
# {'label': 'POSITIVE', 'score': 0.9608806371688843}
# {'label': 'POSITIVE', 'score': 0.5764654874801636}
# {'label': 'POSITIVE', 'score': 0.9965922236442566}
# {'label': 'POSITIVE', 'score': 0.6328222751617432}
# {'label': 'NEGATIVE', 'score': 0.9981269240379333}
# {'label': 'POSITIVE', 'score': 0.9282402992248535}
# {'label': 'NEGATIVE', 'score': 0.688015878200531}
# {'label': 'NEGATIVE', 'score': 0.674768328666687}
# {'label': 'NEGATIVE', 'score': 0.986592710018158}
# {'label': 'NEGATIVE', 'score': 0.9993914365768433}
# {'label': 'POSITIVE', 'score': 0.999108612537384}
# {'label': 'NEGATIVE', 'score': 0.9981497526168823}
# {'label': 'NEGATIVE', 'score': 0.9366700649261475}
# {'label': 'POSITIVE', 'score': 0.9853752851486206}
# {'label': 'NEGATIVE', 'score': 0.6716500520706177}
# {'label': 'NEGATIVE', 'score': 0.9938398003578186}
# {'label': 'NEGATIVE', 'score': 0.9974347949028015}
# {'label': 'NEGATIVE', 'score': 0.6223390102386475}
# {'label': 'NEGATIVE', 'score': 0.9969093203544617}
# {'label': 'NEGATIVE', 'score': 0.9977195858955383}
# {'label': 'POSITIVE', 'score': 0.9841406345367432}
# {'label': 'NEGATIVE', 'score': 0.9727062582969666}

# %%
# creating tokens and fine tuning the model without using pipeline
batch = sentimentanalysis_tokenizer(X_train1,padding = True,truncation = True, max_length = 500,return_tensors = "pt")# if pytorch tensors required )
#batch_tensor = torch.tensor(batch)
#print(batch_tensor)
with torch.no_grad(): #incremental training, turning off the gradient update
     outputs = sentimentanalysis_model(**batch) # unpack the dictionary using
     print("output",outputs)
     predictions = F.softmax(outputs.logits,dim=1)
     print("predictions",predictions)
     labels = torch.argmax(predictions,dim=1)
     print(labels)
     labels = [sentimentanalysis_model.config.id2label[label_id] for label_id in labels.tolist()]
     print(labels)

# %%
# save model and tokenizer for further use
save_dir = "save_new_model"
sentimentanalysis_model.save_pretrained(save_dir)
sentimentanalysis_tokenizer.save_pretrained(save_dir)
# to laad the model again , use model = AutoModelForSequenceClassification.from_pretrained(save_dir)
# Out:
# ('save_new_model/tokenizer_config.json',
#  'save_new_model/special_tokens_map.json',
#  'save_new_model/vocab.txt',
#  'save_new_model/added_tokens.json',
#  'save_new_model/tokenizer.json')

# %%
#Fine Tune Model On Yelp Review Dataset

#1.prepare dataset

from datasets import load_dataset
from transformers import TrainingArguments, Trainer
import numpy as np
import evaluate

yelp_review_dataset = load_dataset("yelp_review_full")
yelp_review_dataset["train"][100]

#2.Tokenize the dataset

tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

def tokenize_function(data):
    return tokenizer(data["text"], padding="max_length", truncation=True)
tokenized_datasets = yelp_review_dataset.map(tokenize_function, batched=True) # apply tokenise on the whole dataset

training_dataset = tokenized_datasets["train"].shuffle(seed=42).select(range(1000)) # split dataset into training and eval
evaluation_dataset = tokenized_datasets["test"].shuffle(seed=42).select(range(1000))

#4.Load pretrained model and training arguments

model = AutoModelForSequenceClassification.from_pretrained("bert-base-cased", num_labels=5)

# %%
training_args = TrainingArguments(output_dir="test_trainer") # arguments that needed to be trained

metric = evaluate.load("accuracy") # define a evaluation metrics to check the performance of the model

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    print("logits",logits)
    print("labels",labels)
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

training_args = TrainingArguments(output_dir="test_trainer", evaluation_strategy="epoch") # define the arguments that you want to fine tune like epoch, learning rate, weight decay and others


trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=training_dataset,
    eval_dataset=evaluation_dataset,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]
#     <div>
#
#       <progress value='161' max='375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [161/375 2:56:45 < 3:57:53, 0.01 it/s, Epoch 1.28/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.301274</td>
#       <td>0.457000</td>
#     </tr>
#   </tbody>
# </table><p>
# logits [[-1.6708539  -1.580868   -0.7467042   1.5813575   1.9689378 ]
#  [-1.7516464  -1.4258888  -0.61818117  1.6569223   1.6960309 ]
#  [ 1.7169452   0.258924   -0.6948955  -0.5178424  -0.26063216]
#  ...
#  [-1.8355628  -1.2533593  -0.4936489   1.4926646   1.3526435 ]
#  [-2.17375    -0.7757919   0.05179653  1.1895063   0.719332  ]
#  [ 0.07947701  1.7976655   0.403203   -0.71973807 -2.041103  ]]
# labels [2 4 1 4 3 4 2 3 2 3 0 0 3 2 2 1 3 1 2 2 1 2 3 1 1 3 4 0 0 2 2 2 1 3 4 0 0
#  1 3 2 0 2 0 0 3 0 3 2 3 0 1 1 3 3 4 4 1 4 1 3 1 0 0 1 4 1 4 3 2 4 1 0 3 3
#  4 1 2 1 0 4 4 4 2 3 3 1 4 0 4 2 3 0 0 0 3 4 0 0 1 4 4 0 0 1 1 0 4 2 2 1 1
#  4 0 4 0 3 2 0 4 4 4 2 0 0 0 1 3 0 2 0 3 2 2 2 0 3 4 3 0 1 0 1 0 0 4 3 3 1
#  3 0 3 4 0 2 1 3 1 3 1 3 1 0 2 0 1 1 0 0 3 3 3 3 3 1 1 0 0 2 3 3 3 1 1 3 4
#  0 1 1 2 2 1 3 0 2 1 1 4 0 2 4 1 1 2 3 3 2 0 1 2 4 4 1 4 2 3 0 1 0 0 2 4 3
#  3 0 1 1 2 0 4 0 3 0 3 2 3 1 2 4 4 2 1 0 3 1 1 1 3 0 3 0 0 2 0 3 0 3 2 4 2
#  2 4 4 1 1 4 4 4 0 4 0 3 1 0 1 2 2 3 0 1 0 4 1 0 4 3 0 0 3 2 1 4 4 3 0 0 0
#  0 3 3 3 4 3 1 0 0 4 3 3 1 0 0 2 1 4 4 1 1 1 3 4 3 0 2 1 4 3 0 1 1 4 1 1 1
#  4 0 2 0 0 2 2 1 2 4 4 4 4 0 2 4 1 1 3 4 1 1 1 0 3 0 2 4 0 2 1 0 3 3 1 1 4
#  0 4 3 4 3 1 1 2 1 2 1 3 2 0 2 4 3 2 3 3 1 0 1 3 4 2 2 1 1 0 1 4 2 2 3 4 3
#  1 4 2 3 3 2 3 1 0 4 2 1 0 4 4 3 0 1 3 2 1 0 0 2 2 3 2 2 4 1 0 1 2 0 4 3 2
#  2 3 0 2 2 0 0 1 4 2 0 1 2 1 1 2 0 3 0 4 1 2 4 3 0 2 2 1 0 1 0 1 2 3 3 4 3
#  4 2 1 0 1 2 3 1 3 1 2 4 1 3 0 4 4 2 2 3 1 3 4 4 4 0 0 0 2 1 2 3 4 4 2 4 3
#  0 3 0 2 1 3 0 0 3 2 0 4 1 4 3 2 4 2 0 1 1 3 3 2 4 3 0 3 2 0 3 3 3 2 1 1 2
#  1 4 1 2 0 3 3 3 3 2 0 1 1 4 4 1 2 2 3 2 0 3 3 0 2 3 0 1 0 3 3 0 1 4 1 1 1
#  2 3 3 2 3 4 0 0 4 4 0 3 0 0 3 1 2 0 2 3 1 2 2 0 0 4 4 0 1 3 1 2 1 3 2 1 4
#  1 3 4 2 4 1 2 0 1 4 2 2 2 4 4 1 0 4 3 1 1 3 1 1 3 3 0 0 0 0 1 2 4 4 1 0 4
#  0 2 0 4 2 2 0 1 0 4 1 3 3 1 1 3 1 0 1 1 1 3 4 2 4 4 4 0 0 1 2 3 0 4 2 4 1
#  3 2 1 4 3 4 2 0 4 1 1 4 1 3 0 4 0 3 4 0 0 0 2 3 1 2 3 3 3 1 2 4 2 2 2 4 3
#  3 2 2 3 2 0 0 1 0 3 4 2 0 3 2 1 2 1 2 0 0 2 0 1 0 3 4 0 4 0 3 2 2 4 0 1 3
#  0 0 3 4 1 4 0 3 1 1 1 1 4 2 2 0 3 0 0 3 3 0 0 3 1 3 0 3 1 3 0 0 4 3 1 0 2
#  0 4 3 1 3 2 0 4 2 2 2 4 2 2 4 2 1 0 3 3 2 0 0 0 2 3 1 2 1 2 1 0 3 4 3 4 1
#  2 0 4 3 1 2 3 0 2 1 2 3 1 1 2 0 3 3 0 3 2 2 1 0 4 2 2 0 2 4 1 0 1 4 4 2 1
#  1 4 4 0 1 2 4 4 1 2 0 1 0 3 3 2 3 0 2 4 4 0 3 0 3 0 2 3 1 2 2 1 2 0 3 2 0
#  3 1 4 0 1 3 1 2 1 4 3 3 0 1 4 3 1 1 2 1 2 3 3 3 0 1 2 2 3 1 4 0 2 3 0 3 0
#  1 0 1 2 1 2 0 4 0 0 0 2 2 1 0 4 4 2 0 4 3 0 4 0 1 2 4 2 0 1 1 3 3 3 3 2 2
#  1]
#     <div>
#
#       <progress value='162' max='375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [162/375 2:57:39 < 3:56:30, 0.02 it/s, Epoch 1.29/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.301274</td>
#       <td>0.457000</td>
#     </tr>
#   </tbody>
# </table><p>
